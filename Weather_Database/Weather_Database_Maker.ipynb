# %%
import time
from datetime import datetime
import requests as rq #importing the requsest <-my spelling is why i used 'rq'
import json
from citipy import citipy #location finder
#import geocoder as gc #personal location finder to add my own spin this
import numpy as np #fancy numpy stuff
from Config import api_key
import pandas as pd

# %%
#create my 
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID='
target_url = f'{url}{api_key}'
#don't print your API key

# %%
#make a list of 2000 random latitude and longitude cords
lats = np.random.uniform(low =-90.000, high=90.000, size=2000)
longt = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, longt) #zip zip zip it up, 
lat_lngs #outputs as zip object time to convert to a list

coordinates = list(lat_lngs)

# %%
cities = [] #create an empty list for the cities

# %%
for cored in coordinates: #tempted to add a loading bar
    city = citipy.nearest_city(cored[0], cored[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities) #in notebook this will print the number of unique cities
# Out:
# 800

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities): #enumerate seems like the right thing to use,probably could've used the number of results tho

    if(i % 50 == 0 and i >= 100):
        set_count += 1
        record_count = 1
        time.sleep(60) #time to
    
    city_url = target_url + '&q=' + city.replace(' ','+')
    print(f'Processing Record {record_count} of Set {set_count} | City: {city}')
    record_count += 1

    try:
        # Parse the JSON and retrieve data.
        city_weather = rq.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except:
        print(f"ERROR WARNING.  CITY NOT FOUND. {city}")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | City: hithadhoo
# Processing Record 2 of Set 1 | City: mataura
# Processing Record 3 of Set 1 | City: bredasdorp
# Processing Record 4 of Set 1 | City: ushuaia
# Processing Record 5 of Set 1 | City: solnechnyy
# Processing Record 6 of Set 1 | City: miri
# Processing Record 7 of Set 1 | City: arraial do cabo
# Processing Record 8 of Set 1 | City: belushya guba
# ERROR WARNING.  CITY NOT FOUND. belushya guba
# Processing Record 9 of Set 1 | City: chapais
# Processing Record 10 of Set 1 | City: buraydah
# Processing Record 11 of Set 1 | City: evensk
# Processing Record 12 of Set 1 | City: atuona
# Processing Record 13 of Set 1 | City: barawe
# ERROR WARNING.  CITY NOT FOUND. barawe
# Processing Record 14 of Set 1 | City: mazatlan
# Processing Record 15 of Set 1 | City: almeirim
# Processing Record 16 of Set 1 | City: narsaq
# Processing Record 17 of Set 1 | City: port alfred
# Processing Record 18 of Set 1 | City: olinala
# Processing Record 19 of Set 1 | City: nguiu
# ERROR WARNING.  CITY NOT FOUND. nguiu
# Processing Record 20 of Set 1 | City: nancha
# Processing Record 21 of Set 1 | City: garden city
# Processing Record 22 of Set 1 | City: longyearbyen
# Processing Record 23 of Set 1 | City: tsihombe
# ERROR WARNING.  CITY NOT FOUND. tsihombe
# Processing Record 24 of Set 1 | City: adrar
# Processing Record 25 of Set 1 | City: lagoa
# Processing Record 26 of Set 1 | City: avarua
# Processing Record 27 of Set 1 | City: punta arenas
# Processing Record 28 of Set 1 | City: barrow
# Processing Record 29 of Set 1 | City: cabatuan
# Processing Record 30 of Set 1 | City: puerto escondido
# Processing Record 31 of Set 1 | City: riyadh
# Processing Record 32 of Set 1 | City: busselton
# Processing Record 33 of Set 1 | City: bethel
# Processing Record 34 of Set 1 | City: killybegs
# Processing Record 35 of Set 1 | City: desaguadero
# Processing Record 36 of Set 1 | City: kanigiri
# Processing Record 37 of Set 1 | City: puerto ayora
# Processing Record 38 of Set 1 | City: la ronge
# Processing Record 39 of Set 1 | City: upernavik
# Processing Record 40 of Set 1 | City: kailua
# Processing Record 41 of Set 1 | City: ucluelet
# Processing Record 42 of Set 1 | City: kyra
# Processing Record 43 of Set 1 | City: alyangula
# Processing Record 44 of Set 1 | City: samusu
# ERROR WARNING.  CITY NOT FOUND. samusu
# Processing Record 45 of Set 1 | City: vila franca do campo
# Processing Record 46 of Set 1 | City: mahebourg
# Processing Record 47 of Set 1 | City: ola
# Processing Record 48 of Set 1 | City: piacabucu
# Processing Record 49 of Set 1 | City: vaini
# Processing Record 50 of Set 1 | City: vanimo
# Processing Record 51 of Set 1 | City: itarema
# Processing Record 52 of Set 1 | City: bolshegrivskoye
# ERROR WARNING.  CITY NOT FOUND. bolshegrivskoye
# Processing Record 53 of Set 1 | City: linares
# Processing Record 54 of Set 1 | City: yablochnyy
# Processing Record 55 of Set 1 | City: sri aman
# Processing Record 56 of Set 1 | City: barentsburg
# ERROR WARNING.  CITY NOT FOUND. barentsburg
# Processing Record 57 of Set 1 | City: tateyama
# Processing Record 58 of Set 1 | City: krasnousolskiy
# ERROR WARNING.  CITY NOT FOUND. krasnousolskiy
# Processing Record 59 of Set 1 | City: dalvik
# Processing Record 60 of Set 1 | City: illoqqortoormiut
# ERROR WARNING.  CITY NOT FOUND. illoqqortoormiut
# Processing Record 61 of Set 1 | City: rikitea
# Processing Record 62 of Set 1 | City: vestmannaeyjar
# Processing Record 63 of Set 1 | City: tuktoyaktuk
# Processing Record 64 of Set 1 | City: kodiak
# Processing Record 65 of Set 1 | City: hilo
# Processing Record 66 of Set 1 | City: turukhansk
# Processing Record 67 of Set 1 | City: hobart
# Processing Record 68 of Set 1 | City: bengkulu
# Processing Record 69 of Set 1 | City: henties bay
# Processing Record 70 of Set 1 | City: iqaluit
# Processing Record 71 of Set 1 | City: gbarnga
# Processing Record 72 of Set 1 | City: shache
# Processing Record 73 of Set 1 | City: cabo san lucas
# Processing Record 74 of Set 1 | City: diu
# Processing Record 75 of Set 1 | City: kochi
# Processing Record 76 of Set 1 | City: tramandai
# Processing Record 77 of Set 1 | City: banda aceh
# Processing Record 78 of Set 1 | City: lavrentiya
# Processing Record 79 of Set 1 | City: charters towers
# Processing Record 80 of Set 1 | City: qaanaaq
# Processing Record 81 of Set 1 | City: bilibino
# Processing Record 82 of Set 1 | City: terra santa
# Processing Record 83 of Set 1 | City: nanortalik
# Processing Record 84 of Set 1 | City: lasa
# Processing Record 85 of Set 1 | City: naryan-mar
# Processing Record 86 of Set 1 | City: warqla
# ERROR WARNING.  CITY NOT FOUND. warqla
# Processing Record 87 of Set 1 | City: obluche
# ERROR WARNING.  CITY NOT FOUND. obluche
# Processing Record 88 of Set 1 | City: puerto colombia
# Processing Record 89 of Set 1 | City: amderma
# ERROR WARNING.  CITY NOT FOUND. amderma
# Processing Record 90 of Set 1 | City: klaksvik
# Processing Record 91 of Set 1 | City: hobyo
# Processing Record 92 of Set 1 | City: gondanglegi
# Processing Record 93 of Set 1 | City: saint-joseph
# Processing Record 94 of Set 1 | City: albany
# Processing Record 95 of Set 1 | City: mys shmidta
# ERROR WARNING.  CITY NOT FOUND. mys shmidta
# Processing Record 96 of Set 1 | City: hermanus
# Processing Record 97 of Set 1 | City: castro
# Processing Record 98 of Set 1 | City: simbach
# Processing Record 99 of Set 1 | City: jiddah
# ERROR WARNING.  CITY NOT FOUND. jiddah
# Processing Record 100 of Set 1 | City: cidreira
# Processing Record 1 of Set 2 | City: asayita
# ERROR WARNING.  CITY NOT FOUND. asayita
# Processing Record 2 of Set 2 | City: auki
# Processing Record 3 of Set 2 | City: taolanaro
# ERROR WARNING.  CITY NOT FOUND. taolanaro
# Processing Record 4 of Set 2 | City: zolotinka
# ERROR WARNING.  CITY NOT FOUND. zolotinka
# Processing Record 5 of Set 2 | City: leningradskiy
# Processing Record 6 of Set 2 | City: attawapiskat
# ERROR WARNING.  CITY NOT FOUND. attawapiskat
# Processing Record 7 of Set 2 | City: port hedland
# Processing Record 8 of Set 2 | City: am timan
# Processing Record 9 of Set 2 | City: bonthe
# Processing Record 10 of Set 2 | City: inzer
# Processing Record 11 of Set 2 | City: san cristobal
# Processing Record 12 of Set 2 | City: mirnyy
# Processing Record 13 of Set 2 | City: dikson
# Processing Record 14 of Set 2 | City: nioro
# Processing Record 15 of Set 2 | City: san jeronimo
# Processing Record 16 of Set 2 | City: hays
# Processing Record 17 of Set 2 | City: saskylakh
# Processing Record 18 of Set 2 | City: mushie
# Processing Record 19 of Set 2 | City: acajutla
# Processing Record 20 of Set 2 | City: mar del plata
# Processing Record 21 of Set 2 | City: yellowknife
# Processing Record 22 of Set 2 | City: cabildo
# Processing Record 23 of Set 2 | City: northam
# Processing Record 24 of Set 2 | City: one hundred mile house
# ERROR WARNING.  CITY NOT FOUND. one hundred mile house
# Processing Record 25 of Set 2 | City: amreli
# Processing Record 26 of Set 2 | City: rorvik
# Processing Record 27 of Set 2 | City: ribeira grande
# Processing Record 28 of Set 2 | City: saint george
# Processing Record 29 of Set 2 | City: west bay
# Processing Record 30 of Set 2 | City: halol
# Processing Record 31 of Set 2 | City: samarai
# Processing Record 32 of Set 2 | City: faya
# Processing Record 33 of Set 2 | City: novovasylivka
# Processing Record 34 of Set 2 | City: sao raimundo nonato
# Processing Record 35 of Set 2 | City: carnarvon
# Processing Record 36 of Set 2 | City: lethem
# Processing Record 37 of Set 2 | City: toliary
# ERROR WARNING.  CITY NOT FOUND. toliary
# Processing Record 38 of Set 2 | City: grindavik
# Processing Record 39 of Set 2 | City: makakilo city
# Processing Record 40 of Set 2 | City: jamestown
# Processing Record 41 of Set 2 | City: georgetown
# Processing Record 42 of Set 2 | City: esna
# Processing Record 43 of Set 2 | City: kaniama
# Processing Record 44 of Set 2 | City: pacific grove
# Processing Record 45 of Set 2 | City: sovetskiy
# Processing Record 46 of Set 2 | City: sao filipe
# Processing Record 47 of Set 2 | City: nizhneyansk
# ERROR WARNING.  CITY NOT FOUND. nizhneyansk
# Processing Record 48 of Set 2 | City: asau
# Processing Record 49 of Set 2 | City: vao
# Processing Record 50 of Set 2 | City: wairoa
# Processing Record 1 of Set 3 | City: port elizabeth
# Processing Record 2 of Set 3 | City: kahului
# Processing Record 3 of Set 3 | City: bonavista
# Processing Record 4 of Set 3 | City: hambantota
# Processing Record 5 of Set 3 | City: tasiilaq
# Processing Record 6 of Set 3 | City: arlit
# Processing Record 7 of Set 3 | City: cuenca
# Processing Record 8 of Set 3 | City: pemberton
# Processing Record 9 of Set 3 | City: cape town
# Processing Record 10 of Set 3 | City: ostersund
# Processing Record 11 of Set 3 | City: yerbogachen
# Processing Record 12 of Set 3 | City: kirkuk
# Processing Record 13 of Set 3 | City: kashi
# Processing Record 14 of Set 3 | City: ohafia
# Processing Record 15 of Set 3 | City: vila
# Processing Record 16 of Set 3 | City: ngukurr
# ERROR WARNING.  CITY NOT FOUND. ngukurr
# Processing Record 17 of Set 3 | City: doha
# Processing Record 18 of Set 3 | City: utiroa
# ERROR WARNING.  CITY NOT FOUND. utiroa
# Processing Record 19 of Set 3 | City: hualmay
# Processing Record 20 of Set 3 | City: banjarmasin
# Processing Record 21 of Set 3 | City: thompson
# Processing Record 22 of Set 3 | City: novobirilyussy
# Processing Record 23 of Set 3 | City: cabra
# Processing Record 24 of Set 3 | City: anloga
# Processing Record 25 of Set 3 | City: lata
# Processing Record 26 of Set 3 | City: bilma
# Processing Record 27 of Set 3 | City: whitecourt
# Processing Record 28 of Set 3 | City: kapaa
# Processing Record 29 of Set 3 | City: chuy
# Processing Record 30 of Set 3 | City: udachnyy
# Processing Record 31 of Set 3 | City: bluff
# Processing Record 32 of Set 3 | City: los llanos de aridane
# Processing Record 33 of Set 3 | City: alihe
# Processing Record 34 of Set 3 | City: ewa beach
# Processing Record 35 of Set 3 | City: sorland
# Processing Record 36 of Set 3 | City: lodja
# Processing Record 37 of Set 3 | City: nieuw amsterdam
# Processing Record 38 of Set 3 | City: rungata
# ERROR WARNING.  CITY NOT FOUND. rungata
# Processing Record 39 of Set 3 | City: padang
# Processing Record 40 of Set 3 | City: bolungarvik
# ERROR WARNING.  CITY NOT FOUND. bolungarvik
# Processing Record 41 of Set 3 | City: hailar
# Processing Record 42 of Set 3 | City: esperance
# Processing Record 43 of Set 3 | City: tuatapere
# Processing Record 44 of Set 3 | City: provideniya
# Processing Record 45 of Set 3 | City: ust-nera
# Processing Record 46 of Set 3 | City: te anau
# Processing Record 47 of Set 3 | City: lebu
# Processing Record 48 of Set 3 | City: aklavik
# Processing Record 49 of Set 3 | City: kaitangata
# Processing Record 50 of Set 3 | City: tabiauea
# ERROR WARNING.  CITY NOT FOUND. tabiauea
# Processing Record 1 of Set 4 | City: dryden
# Processing Record 2 of Set 4 | City: sulangan
# Processing Record 3 of Set 4 | City: severo-kurilsk
# Processing Record 4 of Set 4 | City: halalo
# ERROR WARNING.  CITY NOT FOUND. halalo
# Processing Record 5 of Set 4 | City: kruisfontein
# Processing Record 6 of Set 4 | City: chase
# Processing Record 7 of Set 4 | City: victoria
# Processing Record 8 of Set 4 | City: sentyabrskiy
# ERROR WARNING.  CITY NOT FOUND. sentyabrskiy
# Processing Record 9 of Set 4 | City: zelenoborskiy
# Processing Record 10 of Set 4 | City: alekseyevsk
# Processing Record 11 of Set 4 | City: port-cartier
# Processing Record 12 of Set 4 | City: rawson
# Processing Record 13 of Set 4 | City: laguna
# Processing Record 14 of Set 4 | City: batticaloa
# Processing Record 15 of Set 4 | City: khudumelapye
# Processing Record 16 of Set 4 | City: qom
# Processing Record 17 of Set 4 | City: dongfeng
# Processing Record 18 of Set 4 | City: camacha
# Processing Record 19 of Set 4 | City: grand gaube
# Processing Record 20 of Set 4 | City: andevoranto
# ERROR WARNING.  CITY NOT FOUND. andevoranto
# Processing Record 21 of Set 4 | City: kasongo-lunda
# Processing Record 22 of Set 4 | City: korla
# Processing Record 23 of Set 4 | City: sault sainte marie
# Processing Record 24 of Set 4 | City: perth
# Processing Record 25 of Set 4 | City: ponta do sol
# Processing Record 26 of Set 4 | City: saint-philippe
# Processing Record 27 of Set 4 | City: panalingaan
# Processing Record 28 of Set 4 | City: french harbor
# Processing Record 29 of Set 4 | City: talnakh
# Processing Record 30 of Set 4 | City: salta
# Processing Record 31 of Set 4 | City: torbay
# Processing Record 32 of Set 4 | City: hima
# Processing Record 33 of Set 4 | City: sumbe
# Processing Record 34 of Set 4 | City: rio gallegos
# Processing Record 35 of Set 4 | City: saldanha
# Processing Record 36 of Set 4 | City: wageningen
# Processing Record 37 of Set 4 | City: east london
# Processing Record 38 of Set 4 | City: kavieng
# Processing Record 39 of Set 4 | City: makushino
# Processing Record 40 of Set 4 | City: galiwinku
# ERROR WARNING.  CITY NOT FOUND. galiwinku
# Processing Record 41 of Set 4 | City: ambodifototra
# ERROR WARNING.  CITY NOT FOUND. ambodifototra
# Processing Record 42 of Set 4 | City: clifton
# Processing Record 43 of Set 4 | City: mutsu
# Processing Record 44 of Set 4 | City: ilulissat
# Processing Record 45 of Set 4 | City: berdigestyakh
# Processing Record 46 of Set 4 | City: ballina
# Processing Record 47 of Set 4 | City: ondjiva
# Processing Record 48 of Set 4 | City: tunduru
# ERROR WARNING.  CITY NOT FOUND. tunduru
# Processing Record 49 of Set 4 | City: ostrov
# Processing Record 50 of Set 4 | City: coquimbo
# Processing Record 1 of Set 5 | City: bhan
# Processing Record 2 of Set 5 | City: codrington
# Processing Record 3 of Set 5 | City: nikolskoye
# Processing Record 4 of Set 5 | City: inhambane
# Processing Record 5 of Set 5 | City: kralendijk
# Processing Record 6 of Set 5 | City: vardo
# Processing Record 7 of Set 5 | City: nizhnyaya tavda
# Processing Record 8 of Set 5 | City: matagalpa
# Processing Record 9 of Set 5 | City: rameshki
# Processing Record 10 of Set 5 | City: moussoro
# Processing Record 11 of Set 5 | City: seoul
# Processing Record 12 of Set 5 | City: pisco
# Processing Record 13 of Set 5 | City: stilfontein
# Processing Record 14 of Set 5 | City: aksehir
# Processing Record 15 of Set 5 | City: grand river south east
# ERROR WARNING.  CITY NOT FOUND. grand river south east
# Processing Record 16 of Set 5 | City: chokurdakh
# Processing Record 17 of Set 5 | City: kidal
# Processing Record 18 of Set 5 | City: yei
# Processing Record 19 of Set 5 | City: oranjestad
# Processing Record 20 of Set 5 | City: taoudenni
# Processing Record 21 of Set 5 | City: aykhal
# Processing Record 22 of Set 5 | City: buala
# Processing Record 23 of Set 5 | City: mareeba
# Processing Record 24 of Set 5 | City: zyryanka
# Processing Record 25 of Set 5 | City: shoranur
# Processing Record 26 of Set 5 | City: velikodvorskiy
# Processing Record 27 of Set 5 | City: qaqortoq
# Processing Record 28 of Set 5 | City: qiongshan
# Processing Record 29 of Set 5 | City: boende
# Processing Record 30 of Set 5 | City: cherskiy
# Processing Record 31 of Set 5 | City: visnes
# Processing Record 32 of Set 5 | City: ratnagiri
# Processing Record 33 of Set 5 | City: cayenne
# Processing Record 34 of Set 5 | City: luderitz
# Processing Record 35 of Set 5 | City: grand-santi
# Processing Record 36 of Set 5 | City: srednekolymsk
# Processing Record 37 of Set 5 | City: marienburg
# Processing Record 38 of Set 5 | City: saint-augustin
# Processing Record 39 of Set 5 | City: margate
# Processing Record 40 of Set 5 | City: port hardy
# Processing Record 41 of Set 5 | City: mantua
# Processing Record 42 of Set 5 | City: mudyuga
# ERROR WARNING.  CITY NOT FOUND. mudyuga
# Processing Record 43 of Set 5 | City: ternate
# Processing Record 44 of Set 5 | City: san patricio
# Processing Record 45 of Set 5 | City: felidhoo
# ERROR WARNING.  CITY NOT FOUND. felidhoo
# Processing Record 46 of Set 5 | City: nhulunbuy
# Processing Record 47 of Set 5 | City: jijiga
# Processing Record 48 of Set 5 | City: juba
# Processing Record 49 of Set 5 | City: guangyuan
# Processing Record 50 of Set 5 | City: badvel
# Processing Record 1 of Set 6 | City: jiuquan
# Processing Record 2 of Set 6 | City: monrovia
# Processing Record 3 of Set 6 | City: krasnoye
# Processing Record 4 of Set 6 | City: havoysund
# Processing Record 5 of Set 6 | City: lamar
# Processing Record 6 of Set 6 | City: leshan
# Processing Record 7 of Set 6 | City: kudat
# Processing Record 8 of Set 6 | City: bababe
# ERROR WARNING.  CITY NOT FOUND. bababe
# Processing Record 9 of Set 6 | City: bubaque
# Processing Record 10 of Set 6 | City: lorengau
# Processing Record 11 of Set 6 | City: uglezavodsk
# Processing Record 12 of Set 6 | City: teya
# Processing Record 13 of Set 6 | City: bandarbeyla
# Processing Record 14 of Set 6 | City: aljezur
# Processing Record 15 of Set 6 | City: katangli
# Processing Record 16 of Set 6 | City: cantaura
# Processing Record 17 of Set 6 | City: losinyy
# Processing Record 18 of Set 6 | City: baiyin
# Processing Record 19 of Set 6 | City: naze
# Processing Record 20 of Set 6 | City: shakiso
# Processing Record 21 of Set 6 | City: vaitupu
# ERROR WARNING.  CITY NOT FOUND. vaitupu
# Processing Record 22 of Set 6 | City: merrill
# Processing Record 23 of Set 6 | City: norman wells
# Processing Record 24 of Set 6 | City: olga
# Processing Record 25 of Set 6 | City: palauig
# Processing Record 26 of Set 6 | City: broome
# Processing Record 27 of Set 6 | City: emerald
# Processing Record 28 of Set 6 | City: port lincoln
# Processing Record 29 of Set 6 | City: san rafael
# Processing Record 30 of Set 6 | City: guangshui
# Processing Record 31 of Set 6 | City: mendahara
# ERROR WARNING.  CITY NOT FOUND. mendahara
# Processing Record 32 of Set 6 | City: axim
# Processing Record 33 of Set 6 | City: carutapera
# Processing Record 34 of Set 6 | City: jackson
# Processing Record 35 of Set 6 | City: russell
# Processing Record 36 of Set 6 | City: tiksi
# Processing Record 37 of Set 6 | City: airai
# Processing Record 38 of Set 6 | City: svetlaya
# Processing Record 39 of Set 6 | City: khatanga
# Processing Record 40 of Set 6 | City: cacador
# Processing Record 41 of Set 6 | City: guerrero negro
# Processing Record 42 of Set 6 | City: mendota
# Processing Record 43 of Set 6 | City: katsuura
# Processing Record 44 of Set 6 | City: bambous virieux
# Processing Record 45 of Set 6 | City: nacala
# Processing Record 46 of Set 6 | City: upata
# Processing Record 47 of Set 6 | City: naranjito
# Processing Record 48 of Set 6 | City: moose factory
# Processing Record 49 of Set 6 | City: brejo
# Processing Record 50 of Set 6 | City: goundam
# Processing Record 1 of Set 7 | City: teknaf
# Processing Record 2 of Set 7 | City: olenegorsk
# Processing Record 3 of Set 7 | City: new norfolk
# Processing Record 4 of Set 7 | City: oskemen
# Processing Record 5 of Set 7 | City: souillac
# Processing Record 6 of Set 7 | City: plainview
# Processing Record 7 of Set 7 | City: sasykoli
# Processing Record 8 of Set 7 | City: santa rosa
# Processing Record 9 of Set 7 | City: karonga
# Processing Record 10 of Set 7 | City: kawalu
# Processing Record 11 of Set 7 | City: ostrovnoy
# Processing Record 12 of Set 7 | City: pontypool
# Processing Record 13 of Set 7 | City: laela
# Processing Record 14 of Set 7 | City: meulaboh
# Processing Record 15 of Set 7 | City: slavyanka
# Processing Record 16 of Set 7 | City: koslan
# Processing Record 17 of Set 7 | City: eregli
# Processing Record 18 of Set 7 | City: murom
# Processing Record 19 of Set 7 | City: haimen
# Processing Record 20 of Set 7 | City: ust-omchug
# Processing Record 21 of Set 7 | City: nome
# Processing Record 22 of Set 7 | City: manokwari
# Processing Record 23 of Set 7 | City: richards bay
# Processing Record 24 of Set 7 | City: tocache
# Processing Record 25 of Set 7 | City: monte carmelo
# Processing Record 26 of Set 7 | City: porto velho
# Processing Record 27 of Set 7 | City: rostovka
# Processing Record 28 of Set 7 | City: aron
# Processing Record 29 of Set 7 | City: sawakin
# Processing Record 30 of Set 7 | City: barabai
# Processing Record 31 of Set 7 | City: takoradi
# Processing Record 32 of Set 7 | City: tual
# Processing Record 33 of Set 7 | City: norton
# Processing Record 34 of Set 7 | City: homun
# Processing Record 35 of Set 7 | City: aleksandrov gay
# Processing Record 36 of Set 7 | City: praia da vitoria
# Processing Record 37 of Set 7 | City: saleaula
# ERROR WARNING.  CITY NOT FOUND. saleaula
# Processing Record 38 of Set 7 | City: labuhan
# Processing Record 39 of Set 7 | City: namalenga
# Processing Record 40 of Set 7 | City: trairi
# Processing Record 41 of Set 7 | City: smithers
# Processing Record 42 of Set 7 | City: sola
# Processing Record 43 of Set 7 | City: agar
# Processing Record 44 of Set 7 | City: peyima
# Processing Record 45 of Set 7 | City: lazaro cardenas
# Processing Record 46 of Set 7 | City: batagay
# Processing Record 47 of Set 7 | City: yantal
# Processing Record 48 of Set 7 | City: ovalle
# Processing Record 49 of Set 7 | City: roma
# Processing Record 50 of Set 7 | City: bocas del toro
# Processing Record 1 of Set 8 | City: fort saint john
# ERROR WARNING.  CITY NOT FOUND. fort saint john
# Processing Record 2 of Set 8 | City: nenjiang
# Processing Record 3 of Set 8 | City: blythe
# Processing Record 4 of Set 8 | City: loa janan
# Processing Record 5 of Set 8 | City: green valley
# Processing Record 6 of Set 8 | City: hami
# Processing Record 7 of Set 8 | City: kanye
# Processing Record 8 of Set 8 | City: qui nhon
# Processing Record 9 of Set 8 | City: puerto ayacucho
# Processing Record 10 of Set 8 | City: butaritari
# Processing Record 11 of Set 8 | City: ancud
# Processing Record 12 of Set 8 | City: aswan
# Processing Record 13 of Set 8 | City: kushima
# Processing Record 14 of Set 8 | City: acarau
# Processing Record 15 of Set 8 | City: yulara
# Processing Record 16 of Set 8 | City: gimli
# Processing Record 17 of Set 8 | City: kholtoson
# Processing Record 18 of Set 8 | City: yumen
# Processing Record 19 of Set 8 | City: belmonte
# Processing Record 20 of Set 8 | City: namibe
# Processing Record 21 of Set 8 | City: mayo
# Processing Record 22 of Set 8 | City: volsk
# Processing Record 23 of Set 8 | City: necochea
# Processing Record 24 of Set 8 | City: ukiah
# Processing Record 25 of Set 8 | City: hamilton
# Processing Record 26 of Set 8 | City: lompoc
# Processing Record 27 of Set 8 | City: beltinci
# Processing Record 28 of Set 8 | City: kieta
# Processing Record 29 of Set 8 | City: faanui
# Processing Record 30 of Set 8 | City: mesquite
# Processing Record 31 of Set 8 | City: ambovombe
# Processing Record 32 of Set 8 | City: fairhope
# Processing Record 33 of Set 8 | City: roald
# Processing Record 34 of Set 8 | City: zhangjiakou
# Processing Record 35 of Set 8 | City: byron bay
# Processing Record 36 of Set 8 | City: redmond
# Processing Record 37 of Set 8 | City: amga
# Processing Record 38 of Set 8 | City: acapulco
# Processing Record 39 of Set 8 | City: hammond
# Processing Record 40 of Set 8 | City: rock sound
# Processing Record 41 of Set 8 | City: turtas
# Processing Record 42 of Set 8 | City: gornopravdinsk
# Processing Record 43 of Set 8 | City: converse
# Processing Record 44 of Set 8 | City: benin
# Processing Record 45 of Set 8 | City: kampot
# Processing Record 46 of Set 8 | City: round rock
# Processing Record 47 of Set 8 | City: koping
# Processing Record 48 of Set 8 | City: aguimes
# Processing Record 49 of Set 8 | City: louisbourg
# ERROR WARNING.  CITY NOT FOUND. louisbourg
# Processing Record 50 of Set 8 | City: champerico
# Processing Record 1 of Set 9 | City: dingle
# Processing Record 2 of Set 9 | City: clyde river
# Processing Record 3 of Set 9 | City: eureka
# Processing Record 4 of Set 9 | City: ondorhaan
# ERROR WARNING.  CITY NOT FOUND. ondorhaan
# Processing Record 5 of Set 9 | City: billings
# Processing Record 6 of Set 9 | City: dubbo
# Processing Record 7 of Set 9 | City: nelson bay
# Processing Record 8 of Set 9 | City: granada
# Processing Record 9 of Set 9 | City: tura
# Processing Record 10 of Set 9 | City: shimoda
# Processing Record 11 of Set 9 | City: mersing
# Processing Record 12 of Set 9 | City: talcahuano
# Processing Record 13 of Set 9 | City: sinnamary
# Processing Record 14 of Set 9 | City: quang ngai
# Processing Record 15 of Set 9 | City: ixtapa
# Processing Record 16 of Set 9 | City: gobabis
# Processing Record 17 of Set 9 | City: toftir
# ERROR WARNING.  CITY NOT FOUND. toftir
# Processing Record 18 of Set 9 | City: urdoma
# Processing Record 19 of Set 9 | City: misratah
# Processing Record 20 of Set 9 | City: tutoia
# Processing Record 21 of Set 9 | City: champoton
# Processing Record 22 of Set 9 | City: kirakira
# Processing Record 23 of Set 9 | City: lindsay
# Processing Record 24 of Set 9 | City: awbari
# Processing Record 25 of Set 9 | City: dickinson
# Processing Record 26 of Set 9 | City: sudak
# Processing Record 27 of Set 9 | City: beyneu
# Processing Record 28 of Set 9 | City: aparecida do taboado
# Processing Record 29 of Set 9 | City: balikpapan
# Processing Record 30 of Set 9 | City: sitka
# Processing Record 31 of Set 9 | City: kaeo
# Processing Record 32 of Set 9 | City: okmulgee
# Processing Record 33 of Set 9 | City: svetlogorsk
# Processing Record 34 of Set 9 | City: thinadhoo
# Processing Record 35 of Set 9 | City: portland
# Processing Record 36 of Set 9 | City: tymovskoye
# Processing Record 37 of Set 9 | City: araouane
# Processing Record 38 of Set 9 | City: nkhata bay
# Processing Record 39 of Set 9 | City: deputatskiy
# Processing Record 40 of Set 9 | City: simbahan
# Processing Record 41 of Set 9 | City: mitu
# Processing Record 42 of Set 9 | City: talara
# Processing Record 43 of Set 9 | City: yar-sale
# Processing Record 44 of Set 9 | City: novyy urengoy
# Processing Record 45 of Set 9 | City: fort-shevchenko
# Processing Record 46 of Set 9 | City: san ramon
# Processing Record 47 of Set 9 | City: aquiraz
# Processing Record 48 of Set 9 | City: londoko
# Processing Record 49 of Set 9 | City: naugarzan
# ERROR WARNING.  CITY NOT FOUND. naugarzan
# Processing Record 50 of Set 9 | City: karaul
# ERROR WARNING.  CITY NOT FOUND. karaul
# Processing Record 1 of Set 10 | City: syracuse
# Processing Record 2 of Set 10 | City: sovetskaya gavan
# Processing Record 3 of Set 10 | City: maniitsoq
# Processing Record 4 of Set 10 | City: yining
# Processing Record 5 of Set 10 | City: khani
# Processing Record 6 of Set 10 | City: snasa
# Processing Record 7 of Set 10 | City: havre-saint-pierre
# Processing Record 8 of Set 10 | City: laiyang
# Processing Record 9 of Set 10 | City: harqalah
# Processing Record 10 of Set 10 | City: saint-gabriel
# Processing Record 11 of Set 10 | City: lieksa
# Processing Record 12 of Set 10 | City: yirol
# ERROR WARNING.  CITY NOT FOUND. yirol
# Processing Record 13 of Set 10 | City: sibolga
# Processing Record 14 of Set 10 | City: sayyan
# Processing Record 15 of Set 10 | City: palmer
# Processing Record 16 of Set 10 | City: dukat
# Processing Record 17 of Set 10 | City: skalistyy
# ERROR WARNING.  CITY NOT FOUND. skalistyy
# Processing Record 18 of Set 10 | City: chicama
# Processing Record 19 of Set 10 | City: karaidel
# Processing Record 20 of Set 10 | City: south bend
# Processing Record 21 of Set 10 | City: palabuhanratu
# ERROR WARNING.  CITY NOT FOUND. palabuhanratu
# Processing Record 22 of Set 10 | City: port angeles
# Processing Record 23 of Set 10 | City: fort nelson
# Processing Record 24 of Set 10 | City: bogomila
# Processing Record 25 of Set 10 | City: kinkala
# Processing Record 26 of Set 10 | City: markova
# Processing Record 27 of Set 10 | City: paranaiba
# Processing Record 28 of Set 10 | City: natal
# Processing Record 29 of Set 10 | City: arman
# Processing Record 30 of Set 10 | City: karratha
# Processing Record 31 of Set 10 | City: jardim
# Processing Record 32 of Set 10 | City: madruga
# Processing Record 33 of Set 10 | City: oranjemund
# Processing Record 34 of Set 10 | City: bereda
# Processing Record 35 of Set 10 | City: tarakan
# Processing Record 36 of Set 10 | City: bone
# Processing Record 37 of Set 10 | City: nouadhibou
# Processing Record 38 of Set 10 | City: kalmunai
# Processing Record 39 of Set 10 | City: urucara
# Processing Record 40 of Set 10 | City: silvan
# Processing Record 41 of Set 10 | City: cantagallo
# Processing Record 42 of Set 10 | City: kaputa
# Processing Record 43 of Set 10 | City: goderich
# Processing Record 44 of Set 10 | City: uttaradit
# Processing Record 45 of Set 10 | City: pineville
# Processing Record 46 of Set 10 | City: kattivakkam
# Processing Record 47 of Set 10 | City: kisangani
# Processing Record 48 of Set 10 | City: ati
# Processing Record 49 of Set 10 | City: vila velha
# Processing Record 50 of Set 10 | City: geresk
# ERROR WARNING.  CITY NOT FOUND. geresk
# Processing Record 1 of Set 11 | City: yelizovo
# Processing Record 2 of Set 11 | City: beringovskiy
# Processing Record 3 of Set 11 | City: quesnel
# Processing Record 4 of Set 11 | City: progreso
# Processing Record 5 of Set 11 | City: guiyang
# Processing Record 6 of Set 11 | City: umzimvubu
# ERROR WARNING.  CITY NOT FOUND. umzimvubu
# Processing Record 7 of Set 11 | City: meyungs
# ERROR WARNING.  CITY NOT FOUND. meyungs
# Processing Record 8 of Set 11 | City: isangel
# Processing Record 9 of Set 11 | City: high rock
# Processing Record 10 of Set 11 | City: rawannawi
# ERROR WARNING.  CITY NOT FOUND. rawannawi
# Processing Record 11 of Set 11 | City: melilla
# Processing Record 12 of Set 11 | City: mackay
# Processing Record 13 of Set 11 | City: marcona
# ERROR WARNING.  CITY NOT FOUND. marcona
# Processing Record 14 of Set 11 | City: rantepao
# Processing Record 15 of Set 11 | City: bulungu
# Processing Record 16 of Set 11 | City: vicksburg
# Processing Record 17 of Set 11 | City: turkistan
# Processing Record 18 of Set 11 | City: portlethen
# Processing Record 19 of Set 11 | City: pandhurna
# Processing Record 20 of Set 11 | City: ballitoville
# Processing Record 21 of Set 11 | City: bayan
# Processing Record 22 of Set 11 | City: skibbereen
# Processing Record 23 of Set 11 | City: mogadouro
# Processing Record 24 of Set 11 | City: yeniseysk
# Processing Record 25 of Set 11 | City: haines junction
# Processing Record 26 of Set 11 | City: lyubeshiv
# ERROR WARNING.  CITY NOT FOUND. lyubeshiv
# Processing Record 27 of Set 11 | City: tianpeng
# Processing Record 28 of Set 11 | City: dunedin
# Processing Record 29 of Set 11 | City: potsdam
# Processing Record 30 of Set 11 | City: luena
# Processing Record 31 of Set 11 | City: gornyy
# Processing Record 32 of Set 11 | City: atar
# Processing Record 33 of Set 11 | City: cuamba
# Processing Record 34 of Set 11 | City: pucallpa
# Processing Record 35 of Set 11 | City: zaysan
# Processing Record 36 of Set 11 | City: ust-tsilma
# Processing Record 37 of Set 11 | City: dekar
# Processing Record 38 of Set 11 | City: zhitikara
# ERROR WARNING.  CITY NOT FOUND. zhitikara
# Processing Record 39 of Set 11 | City: dok kham tai
# Processing Record 40 of Set 11 | City: vannes
# Processing Record 41 of Set 11 | City: diplo
# Processing Record 42 of Set 11 | City: cervo
# Processing Record 43 of Set 11 | City: sobolevo
# Processing Record 44 of Set 11 | City: muros
# Processing Record 45 of Set 11 | City: aviles
# Processing Record 46 of Set 11 | City: yenagoa
# Processing Record 47 of Set 11 | City: tam ky
# Processing Record 48 of Set 11 | City: weinan
# Processing Record 49 of Set 11 | City: coahuayana
# Processing Record 50 of Set 11 | City: geraldton
# Processing Record 1 of Set 12 | City: kazbegi
# ERROR WARNING.  CITY NOT FOUND. kazbegi
# Processing Record 2 of Set 12 | City: crixas
# Processing Record 3 of Set 12 | City: canmore
# Processing Record 4 of Set 12 | City: birao
# Processing Record 5 of Set 12 | City: ahuimanu
# Processing Record 6 of Set 12 | City: fairbanks
# Processing Record 7 of Set 12 | City: olinda
# Processing Record 8 of Set 12 | City: touros
# Processing Record 9 of Set 12 | City: arkhangelos
# ERROR WARNING.  CITY NOT FOUND. arkhangelos
# Processing Record 10 of Set 12 | City: qasigiannguit
# Processing Record 11 of Set 12 | City: ust-koksa
# Processing Record 12 of Set 12 | City: verkhnyachka
# Processing Record 13 of Set 12 | City: bolshoye sorokino
# ERROR WARNING.  CITY NOT FOUND. bolshoye sorokino
# Processing Record 14 of Set 12 | City: ulaangom
# Processing Record 15 of Set 12 | City: tsabong
# Processing Record 16 of Set 12 | City: lufilufi
# Processing Record 17 of Set 12 | City: aksum
# Processing Record 18 of Set 12 | City: romitan
# Processing Record 19 of Set 12 | City: krivosheino
# Processing Record 20 of Set 12 | City: chinsali
# Processing Record 21 of Set 12 | City: santa isabel do rio negro
# Processing Record 22 of Set 12 | City: matara
# Processing Record 23 of Set 12 | City: zhangye
# Processing Record 24 of Set 12 | City: ruatoria
# ERROR WARNING.  CITY NOT FOUND. ruatoria
# Processing Record 25 of Set 12 | City: chateau-gontier
# Processing Record 26 of Set 12 | City: viedma
# Processing Record 27 of Set 12 | City: beloha
# Processing Record 28 of Set 12 | City: pavlodar
# Processing Record 29 of Set 12 | City: peleduy
# Processing Record 30 of Set 12 | City: dolhasca
# Processing Record 31 of Set 12 | City: qeshm
# Processing Record 32 of Set 12 | City: cruden bay
# ERROR WARNING.  CITY NOT FOUND. cruden bay
# Processing Record 33 of Set 12 | City: javanrud
# Processing Record 34 of Set 12 | City: balakhta
# Processing Record 35 of Set 12 | City: karamea
# ERROR WARNING.  CITY NOT FOUND. karamea
# Processing Record 36 of Set 12 | City: ilheus
# Processing Record 37 of Set 12 | City: half moon bay
# Processing Record 38 of Set 12 | City: tumannyy
# ERROR WARNING.  CITY NOT FOUND. tumannyy
# Processing Record 39 of Set 12 | City: mrirt
# ERROR WARNING.  CITY NOT FOUND. mrirt
# Processing Record 40 of Set 12 | City: waddan
# Processing Record 41 of Set 12 | City: bonnyville
# Processing Record 42 of Set 12 | City: saint-pierre
# Processing Record 43 of Set 12 | City: manaus
# Processing Record 44 of Set 12 | City: dzhebariki-khaya
# Processing Record 45 of Set 12 | City: pevek
# Processing Record 46 of Set 12 | City: kismayo
# Processing Record 47 of Set 12 | City: zhanatas
# ERROR WARNING.  CITY NOT FOUND. zhanatas
# Processing Record 48 of Set 12 | City: kamenskoye
# ERROR WARNING.  CITY NOT FOUND. kamenskoye
# Processing Record 49 of Set 12 | City: abha
# Processing Record 50 of Set 12 | City: villa del rosario
# Processing Record 1 of Set 13 | City: shakawe
# Processing Record 2 of Set 13 | City: vagur
# Processing Record 3 of Set 13 | City: awjilah
# Processing Record 4 of Set 13 | City: maxixe
# Processing Record 5 of Set 13 | City: bairiki
# Processing Record 6 of Set 13 | City: bathsheba
# Processing Record 7 of Set 13 | City: iquitos
# Processing Record 8 of Set 13 | City: mahon
# Processing Record 9 of Set 13 | City: cabaiguan
# Processing Record 10 of Set 13 | City: kupang
# Processing Record 11 of Set 13 | City: stawell
# Processing Record 12 of Set 13 | City: impfondo
# Processing Record 13 of Set 13 | City: oum hadjer
# Processing Record 14 of Set 13 | City: mirina
# ERROR WARNING.  CITY NOT FOUND. mirina
# Processing Record 15 of Set 13 | City: abu kamal
# Processing Record 16 of Set 13 | City: teberda
# Processing Record 17 of Set 13 | City: belle fourche
# Processing Record 18 of Set 13 | City: coihaique
# Processing Record 19 of Set 13 | City: rabo de peixe
# Processing Record 20 of Set 13 | City: buchanan
# Processing Record 21 of Set 13 | City: port macquarie
# Processing Record 22 of Set 13 | City: longonjo
# Processing Record 23 of Set 13 | City: zhigansk
# Processing Record 24 of Set 13 | City: mount gambier
# Processing Record 25 of Set 13 | City: oktyabrskoye
# Processing Record 26 of Set 13 | City: anadyr
# Processing Record 27 of Set 13 | City: treinta y tres
# Processing Record 28 of Set 13 | City: sterling
# Processing Record 29 of Set 13 | City: szprotawa
# Processing Record 30 of Set 13 | City: jiexiu
# Processing Record 31 of Set 13 | City: coolum beach
# Processing Record 32 of Set 13 | City: pahrump
# Processing Record 33 of Set 13 | City: itaituba
# Processing Record 34 of Set 13 | City: pochutla
# Processing Record 35 of Set 13 | City: vila do maio
# Processing Record 36 of Set 13 | City: shumskiy
# Processing Record 37 of Set 13 | City: high prairie
# Processing Record 38 of Set 13 | City: warri
# Processing Record 39 of Set 13 | City: nuuk
# Processing Record 40 of Set 13 | City: bogorodskoye
# Processing Record 41 of Set 13 | City: avera
# Processing Record 42 of Set 13 | City: qingdao
# Processing Record 43 of Set 13 | City: brae
# Processing Record 44 of Set 13 | City: kenai
# Processing Record 45 of Set 13 | City: usinsk
# Processing Record 46 of Set 13 | City: shubarkuduk
# Processing Record 47 of Set 13 | City: black river
# Processing Record 48 of Set 13 | City: caraquet
# Processing Record 49 of Set 13 | City: honningsvag
# Processing Record 50 of Set 13 | City: hvammstangi
# ERROR WARNING.  CITY NOT FOUND. hvammstangi
# Processing Record 1 of Set 14 | City: dalen
# Processing Record 2 of Set 14 | City: esil
# Processing Record 3 of Set 14 | City: kishorganj
# Processing Record 4 of Set 14 | City: poum
# Processing Record 5 of Set 14 | City: maragogi
# Processing Record 6 of Set 14 | City: pindi bhattian
# Processing Record 7 of Set 14 | City: vuktyl
# Processing Record 8 of Set 14 | City: great falls
# Processing Record 9 of Set 14 | City: piet retief
# Processing Record 10 of Set 14 | City: barcelos
# Processing Record 11 of Set 14 | City: nerchinskiy zavod
# Processing Record 12 of Set 14 | City: vilhena
# Processing Record 13 of Set 14 | City: kavadarci
# Processing Record 14 of Set 14 | City: omsukchan
# Processing Record 15 of Set 14 | City: marsabit
# Processing Record 16 of Set 14 | City: trapani
# Processing Record 17 of Set 14 | City: falmouth
# Processing Record 18 of Set 14 | City: mo i rana
# Processing Record 19 of Set 14 | City: maputo
# Processing Record 20 of Set 14 | City: jumla
# Processing Record 21 of Set 14 | City: krasnoselkup
# Processing Record 22 of Set 14 | City: saint-georges
# Processing Record 23 of Set 14 | City: rio brilhante
# Processing Record 24 of Set 14 | City: thoen
# Processing Record 25 of Set 14 | City: husavik
# Processing Record 26 of Set 14 | City: prince rupert
# Processing Record 27 of Set 14 | City: port-gentil
# Processing Record 28 of Set 14 | City: torrelavega
# Processing Record 29 of Set 14 | City: acari
# Processing Record 30 of Set 14 | City: matagami
# Processing Record 31 of Set 14 | City: labutta
# ERROR WARNING.  CITY NOT FOUND. labutta
# Processing Record 32 of Set 14 | City: gold coast
# Processing Record 33 of Set 14 | City: taiyuan
# Processing Record 34 of Set 14 | City: kleck
# ERROR WARNING.  CITY NOT FOUND. kleck
# Processing Record 35 of Set 14 | City: plouzane
# Processing Record 36 of Set 14 | City: ponyri
# Processing Record 37 of Set 14 | City: uglich
# Processing Record 38 of Set 14 | City: moerai
# Processing Record 39 of Set 14 | City: hasaki
# Processing Record 40 of Set 14 | City: rio grande
# Processing Record 41 of Set 14 | City: omutinskoye
# ERROR WARNING.  CITY NOT FOUND. omutinskoye
# Processing Record 42 of Set 14 | City: khon buri
# Processing Record 43 of Set 14 | City: trabzon
# Processing Record 44 of Set 14 | City: malinovskiy
# Processing Record 45 of Set 14 | City: berlevag
# Processing Record 46 of Set 14 | City: noyabrsk
# Processing Record 47 of Set 14 | City: tautira
# Processing Record 48 of Set 14 | City: okhotsk
# Processing Record 49 of Set 14 | City: new london
# Processing Record 50 of Set 14 | City: okrika
# Processing Record 1 of Set 15 | City: luganville
# Processing Record 2 of Set 15 | City: daxian
# ERROR WARNING.  CITY NOT FOUND. daxian
# Processing Record 3 of Set 15 | City: amapa
# Processing Record 4 of Set 15 | City: sangar
# Processing Record 5 of Set 15 | City: regeneracao
# Processing Record 6 of Set 15 | City: comodoro rivadavia
# Processing Record 7 of Set 15 | City: novyy urgal
# Processing Record 8 of Set 15 | City: ambilobe
# Processing Record 9 of Set 15 | City: santander jimenez
# Processing Record 10 of Set 15 | City: milkovo
# Processing Record 11 of Set 15 | City: lillebonne
# Processing Record 12 of Set 15 | City: somanda
# Processing Record 13 of Set 15 | City: zacualpan
# Processing Record 14 of Set 15 | City: moron
# Processing Record 15 of Set 15 | City: chagda
# ERROR WARNING.  CITY NOT FOUND. chagda
# Processing Record 16 of Set 15 | City: duluth
# Processing Record 17 of Set 15 | City: tawnat
# ERROR WARNING.  CITY NOT FOUND. tawnat
# Processing Record 18 of Set 15 | City: venado tuerto
# Processing Record 19 of Set 15 | City: pendleton
# Processing Record 20 of Set 15 | City: vostok
# Processing Record 21 of Set 15 | City: ndjole
# Processing Record 22 of Set 15 | City: batemans bay
# Processing Record 23 of Set 15 | City: port augusta
# Processing Record 24 of Set 15 | City: hofn
# Processing Record 25 of Set 15 | City: shitanjing
# Processing Record 26 of Set 15 | City: ust-bolsheretsk
# ERROR WARNING.  CITY NOT FOUND. ust-bolsheretsk
# Processing Record 27 of Set 15 | City: kungurtug
# Processing Record 28 of Set 15 | City: benghazi
# Processing Record 29 of Set 15 | City: moses lake
# Processing Record 30 of Set 15 | City: indramayu
# Processing Record 31 of Set 15 | City: verkh-neyvinskiy
# Processing Record 32 of Set 15 | City: ugoofaaru
# Processing Record 33 of Set 15 | City: miracema do tocantins
# Processing Record 34 of Set 15 | City: nongpoh
# Processing Record 35 of Set 15 | City: yatou
# Processing Record 36 of Set 15 | City: hefei
# Processing Record 37 of Set 15 | City: ojinaga
# Processing Record 38 of Set 15 | City: college
# Processing Record 39 of Set 15 | City: ulladulla
# Processing Record 40 of Set 15 | City: porto novo
# Processing Record 41 of Set 15 | City: road town
# Processing Record 42 of Set 15 | City: meadow lake
# Processing Record 43 of Set 15 | City: port moresby
# Processing Record 44 of Set 15 | City: port blair
# Processing Record 45 of Set 15 | City: carman
# Processing Record 46 of Set 15 | City: chernyshevskiy
# Processing Record 47 of Set 15 | City: santa marta
# Processing Record 48 of Set 15 | City: mmabatho
# Processing Record 49 of Set 15 | City: fortuna
# Processing Record 50 of Set 15 | City: timra

# %%
print('------------------------')
print("Data Retrieval Complete") #loading bar would've been cool though.
#Also would've been faster to split the data in threads using "threading module"
#Not sure if requests can handle that though. and it is outside of the scope of this project.
# Out:
# ------------------------
# Data Retrieval Complete

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(100)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hithadhoo  -0.6000   73.0833     80.78        66           0
# 1        Mataura -46.1927  168.8643     46.47        52          92
# 2     Bredasdorp -34.5322   20.0403     53.42        92          18
# 3        Ushuaia -54.8000  -68.3000     35.26        87          40
# 4     Solnechnyy  50.7214  136.6319     57.40        51          99
# ..           ...      ...       ...       ...       ...         ...
# 95         Nioro  13.3500  -15.7500     77.00        92           0
# 96  San Jeronimo -11.9472  -75.2829     50.68        77          85
# 97          Hays  30.0502  -98.0336     86.09        57          94
# 98     Saskylakh  71.9167  114.0833     31.41        81         100
# 99        Mushie  -3.0167   16.9000     75.70        83          99
#
#     Wind Speed Country                 Date
# 0         3.06      MV  2022-09-16 00:45:21
# 1         4.90      NZ  2022-09-16 00:45:21
# 2         3.65      ZA  2022-09-16 00:45:22
# 3        26.46      AR  2022-09-16 00:45:23
# 4         2.53      RU  2022-09-16 00:45:23
# ..         ...     ...                  ...
# 95        5.99      GM  2022-09-16 00:44:19
# 96        2.93      PE  2022-09-16 00:46:59
# 97        5.01      US  2022-09-16 00:47:00
# 98        9.93      RU  2022-09-16 00:47:00
# 99        1.63      CD  2022-09-16 00:44:26
#
# [100 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv('cities.csv', index_label="City_ID")
